# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveen148/Naveen-M/blob/main/Assignment5_6_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %% [markdown]
# # Assignment5

# %% [markdown]
# ## Ground Cricket Chirps
#
# In _The Song of Insects_ (1948) by George W. Pierce, Pierce mechanically measured the frequency (the number of wing vibrations per second) of chirps (or pulses of sound) made by a striped ground cricket, at various ground temperatures.  Since crickets are ectotherms (cold-blooded), the rate of their physiological processes and their overall metabolism are influenced by temperature.  Consequently, there is reason to believe that temperature would have a profound effect on aspects of their behavior, such as chirp frequency.
#
# In general, it was found that crickets did not sing at temperatures colder than 60º F. or warmer than 100º F.

# %%
ground_cricket_data = {"Chirps/Second": [20.0, 16.0, 19.8, 18.4, 17.1, 15.5, 14.7,
                                         15.7, 15.4, 16.3, 15.0, 17.2, 16.0, 17.0,
                                         14.4],
                       "Ground Temperature": [88.6, 71.6, 93.3, 84.3, 80.6, 75.2, 69.7,
                                              71.6, 69.4, 83.3, 79.6, 82.6, 80.6, 83.5,
                                              76.3]}
df = pd.DataFrame(ground_cricket_data)

# %% [markdown]
# ### Tasks
#
# 1. Find the linear regression equation for this data.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's $R^2$ score (use the `.score` method) to determine whether the
# equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)
# 4. Extrapolate data:  If the ground temperature reached 95, then at what approximate rate would you expect the crickets to be chirping?
# 5. Interpolate data:  With a listening device, you discovered that on a particular morning the crickets were chirping at a rate of 18 chirps per second.  What was the approximate ground temperature that morning?

# %%
df = pd.DataFrame(ground_cricket_data)

# %%
df.head()
# Out:
#    Chirps/Second  Ground Temperature
# 0           20.0                88.6
# 1           16.0                71.6
# 2           19.8                93.3
# 3           18.4                84.3
# 4           17.1                80.6

# %%
df.describe()
# Out:
#        Chirps/Second  Ground Temperature
# count      15.000000           15.000000
# mean       16.566667           79.346667
# std         1.712837            7.020467
# min        14.400000           69.400000
# 25%        15.450000           73.400000
# 50%        16.000000           80.600000
# 75%        17.150000           83.400000
# max        20.000000           93.300000

# %%
df.isnull().sum()
# Out:
# Chirps/Second         0
# Ground Temperature    0
# dtype: int64

# %%
df.dtypes
# Out:
# Chirps/Second         float64
# Ground Temperature    float64
# dtype: object

# %%
df = df.drop_duplicates()

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Chirps/Second', y='Ground Temperature', data=df, s=200)
plt.title("ground_cricket_data", y=1.015, fontsize=20)
plt.xlabel("Chirps/Second", labelpad=13)
plt.ylabel("Ground Temperature", labelpad=13)
ax = plt.gca()

# %%
df.corr()
# Out:
#                     Chirps/Second  Ground Temperature
# Chirps/Second            1.000000            0.832042
# Ground Temperature       0.832042            1.000000

# %%
x = df[['Chirps/Second']].values 
y = df['Ground Temperature'].values

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()
regressor.fit(x, y)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# 22.848982308066887

# %%
print(regressor.coef_)
# Out:
# [3.410323]

# %%
y_pred = regressor.predict(x)
y_pred
# Out:
# array([91.0554423, 77.4141503, 90.3733777, 85.5989255, 81.1655056,
#        75.7089888, 72.9807304, 76.3910534, 75.3679565, 78.4372472,
#        74.0038273, 81.5065379, 77.4141503, 80.8244733, 71.9576335])

# %%
df = pd.DataFrame({'Actual': y, 'Predicted': y_pred})
df
# Out:
#     Actual  Predicted
# 0     88.6  91.055442
# 1     71.6  77.414150
# 2     93.3  90.373378
# 3     84.3  85.598925
# 4     80.6  81.165506
# 5     75.2  75.708989
# 6     69.7  72.980730
# 7     71.6  76.391053
# 8     69.4  75.367957
# 9     83.3  78.437247
# 10    79.6  74.003827
# 11    82.6  81.506538
# 12    80.6  77.414150
# 13    83.5  80.824473
# 14    76.3  71.957634

# %%
regressor.predict([[21.16]])
# Out:
# array([95.01141698])

# %%
regressor.predict([[18]])
# Out:
# array([84.2347963])

# %% [markdown]
# # `evaluation **metric**`

# %%
from sklearn import metrics 
print('R2- SCORE:', metrics.r2_score(y,y_pred))
# Out:
# R2- SCORE: 0.6922946529147003

# %% [markdown]
# # Assignment6

# %% [markdown]
# ## Brain vs. Body Weight
#
# In the file `brain_body.txt`, the average brain and body weight for a number of mammal species are recorded. Load this data into a Pandas data frame.
#
# ### Tasks
#
# 1. Find the linear regression equation for this data for brain weight to body weight.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's $R^2$ score (use the `.score` method) to determine whether the
# equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)

# %%
df1 = pd.read_fwf("brain_body.txt")

# %%
df1.head()
# Out:
#      Brain   Body
# 0    3.385   44.5
# 1    0.480   15.5
# 2    1.350    8.1
# 3  465.000  423.0
# 4   36.330  119.5

# %%
df1.isnull().sum()
# Out:
# Brain    0
# Body     0
# dtype: int64

# %%
df1.dtypes
# Out:
# Brain    float64
# Body     float64
# dtype: object

# %%
df1.describe()
# Out:
#              Brain         Body
# count    62.000000    62.000000
# mean    198.789984   283.134194
# std     899.158011   930.278942
# min       0.005000     0.140000
# 25%       0.600000     4.250000
# 50%       3.342500    17.250000
# 75%      48.202500   166.000000
# max    6654.000000  5712.000000

# %%
df1.drop_duplicates()
# Out:
#       Brain   Body
# 0     3.385   44.5
# 1     0.480   15.5
# 2     1.350    8.1
# 3   465.000  423.0
# 4    36.330  119.5
# ..      ...    ...
# 57  160.000  169.0
# 58    0.900    2.6
# 59    1.620   11.4
# 60    0.104    2.5
# 61    4.235   50.4
#
# [62 rows x 2 columns]

# %%
df1.head()
# Out:
#      Brain   Body
# 0    3.385   44.5
# 1    0.480   15.5
# 2    1.350    8.1
# 3  465.000  423.0
# 4   36.330  119.5

# %% [markdown]
# # **e d m**

# %%
df1.plot(x='Brain', y='Body', style='o')
plt.title('Brain vs Body weight')
plt.xlabel('Brain')
plt.ylabel('body')
plt.show()

# %%
df1.groupby('Brain')['Body'].mean().plot()
plt.title('brain body weght')
plt.xlabel('brain')
plt.ylabel('body')
plt.show()

# %%
x = df1[['Brain']].values 
y = df1['Body'].values

# %%
from sklearn.model_selection import train_test_split #import the required function
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=20)

# %%
df1.corr()
# Out:
#              Actual  Predicted
# Actual     1.000000   0.974526
# Predicted  0.974526   1.000000

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# 84.3503850416374

# %%
print(regressor.coef_)
# Out:
# [0.85159136]

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([ 115.28869899,   87.16063651,   85.79809035,   85.72996304,
#         135.44586637,   85.2019764 ,  247.8559253 ,  107.90540194,
#          84.39126143,  297.24822392,   84.41425439,   85.50003337,
#          92.8662986 ,   84.98907856,   87.91855282,   84.75914889,
#          85.11681726,  156.73565026, 2253.35356755])

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1
# Out:
#      Actual    Predicted
# 0    119.50   115.288699
# 1     25.60    87.160637
# 2      6.30    85.798090
# 3     11.40    85.729963
# 4     81.00   135.445866
# 5      6.60    85.201976
# 6    180.00   247.855925
# 7    115.00   107.905402
# 8      0.33    84.391261
# 9    490.00   297.248224
# 10     1.20    84.414254
# 11     8.10    85.500033
# 12   115.00    92.866299
# 13    12.30    84.989079
# 14    58.00    87.918553
# 15    15.50    84.759149
# 16     2.60    85.116817
# 17   325.00   156.735650
# 18  4603.00  2253.353568

# %%
regressor.predict([[9.5]])
# Out:
# array([92.44050292])

# %%
from sklearn import metrics 
print('R2- SCORE:', metrics.r2_score(y_test,y_pred))
# Out:
# R2- SCORE: 0.7116759859568571

# %% [markdown]
# # Assignment7

# %% [markdown]
# ## Salary Discrimination
#
# The file `salary.txt` contains data for 52 tenure-track professors at a small Midwestern college. This data was used in legal proceedings in the 1980s about discrimination against women in salary.
#
# The data in the file, by column:
#
# 1. Sex. 1 for female, 0 for male.
# 2. Rank. 1 for assistant professor, 2 for associate professor, 3 for full professor.
# 3. Year. Number of years in current rank.
# 4. Degree. Highest degree. 1 for doctorate, 0 for master's.
# 5. YSdeg. Years since highest degree was earned.
# 6. Salary. Salary/year in dollars.
#
# ### Tasks
#
# 1. Find the linear regression equation for this data using columns 1-5 to column 6.
# 2. Find the selection of columns with the best $R^2$ score.
# 3. Report whether sex is a factor in salary.

# %%
df = pd.read_fwf("salary.txt", header=None, 
                 names=["Sex", "Rank", "Year", "Degree", "YSdeg", "Salary"])

# %%
df.head()
# Out:
#    Sex  Rank  Year  Degree  YSdeg  Salary
# 0    0     3    25       1     35   36350
# 1    0     3    13       1     22   35350
# 2    0     3    10       1     23   28200
# 3    1     3     7       1     27   26775
# 4    0     3    19       0     30   33696

# %%
df.isnull().sum()
# Out:
# Sex       0
# Rank      0
# Year      0
# Degree    0
# YSdeg     0
# Salary    0
# dtype: int64

# %%
df.dtypes
# Out:
# Sex       int64
# Rank      int64
# Year      int64
# Degree    int64
# YSdeg     int64
# Salary    int64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#     Sex  Rank  Year  Degree  YSdeg  Salary
# 0     0     3    25       1     35   36350
# 1     0     3    13       1     22   35350
# 2     0     3    10       1     23   28200
# 3     1     3     7       1     27   26775
# 4     0     3    19       0     30   33696
# 5     0     3    16       1     21   28516
# 6     1     3     0       0     32   24900
# 7     0     3    16       1     18   31909
# 8     0     3    13       0     30   31850
# 9     0     3    13       0     31   32850
# 10    0     3    12       1     22   27025
# 11    0     2    15       1     19   24750
# 12    0     3     9       1     17   28200
# 13    0     2     9       0     27   23712
# 14    0     3     9       1     24   25748
# 15    0     3     7       1     15   29342
# 16    0     3    13       1     20   31114
# 17    0     2    11       0     14   24742
# 18    0     2    10       0     15   22906
# 19    0     3     6       0     21   24450
# 20    0     1    16       0     23   19175
# 21    0     2     8       0     31   20525
# 22    0     3     7       1     13   27959
# 23    1     3     8       1     24   38045
# 24    0     2     9       1     12   24832
# 25    0     3     5       1     18   25400
# 26    0     2    11       1     14   24800
# 27    1     3     5       1     16   25500
# 28    0     2     3       0      7   26182
# 29    0     2     3       0     17   23725
# 30    1     1    10       0     15   21600
# 31    0     2    11       0     31   23300
# 32    0     1     9       0     14   23713
# 33    1     2     4       0     33   20690
# 34    1     2     6       0     29   22450
# 35    0     2     1       1      9   20850
# 36    1     1     8       1     14   18304
# 37    0     1     4       1      4   17095
# 38    0     1     4       1      5   16700
# 39    0     1     4       1      4   17600
# 40    0     1     3       1      4   18075
# 41    0     1     3       0     11   18000
# 42    0     2     0       1      7   20999
# 43    1     1     3       1      3   17250
# 44    0     1     2       1      3   16500
# 45    0     1     2       1      1   16094
# 46    1     1     2       1      6   16150
# 47    1     1     2       1      2   15350
# 48    0     1     1       1      1   16244
# 49    1     1     1       1      1   16686
# 50    1     1     1       1      1   15000
# 51    1     1     0       1      2   20300

# %%
df.describe()
# Out:
#              Sex       Rank       Year     Degree      YSdeg        Salary
# count  52.000000  52.000000  52.000000  52.000000  52.000000     52.000000
# mean    0.269231   2.038462   7.480769   0.653846  16.115385  23797.653846
# std     0.447888   0.862316   5.507536   0.480384  10.222340   5917.289154
# min     0.000000   1.000000   0.000000   0.000000   1.000000  15000.000000
# 25%     0.000000   1.000000   3.000000   0.000000   6.750000  18246.750000
# 50%     0.000000   2.000000   7.000000   1.000000  15.500000  23719.000000
# 75%     1.000000   3.000000  11.000000   1.000000  23.250000  27258.500000
# max     1.000000   3.000000  25.000000   1.000000  35.000000  38045.000000

# %%
df.corr()
# Out:
#              Sex      Rank      Year    Degree     YSdeg    Salary
# Sex     1.000000 -0.230411 -0.379404  0.077112 -0.088288 -0.252782
# Rank   -0.230411  1.000000  0.507980 -0.014564  0.695724  0.867488
# Year   -0.379404  0.507980  1.000000 -0.143377  0.638776  0.700669
# Degree  0.077112 -0.014564 -0.143377  1.000000 -0.482836 -0.069726
# YSdeg  -0.088288  0.695724  0.638776 -0.482836  1.000000  0.674854
# Salary -0.252782  0.867488  0.700669 -0.069726  0.674854  1.000000

# %%
x = df[['Rank','Year','Degree','YSdeg','Salary']].values 
y = df['Sex'].values

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()
regressor.fit(x, y)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# -0.047329567632992064

# %%
print(regressor.coef_)
# Out:
# [-4.28417550e-01 -6.26361632e-02  3.82932597e-01  3.86242365e-02
#   3.30123419e-05]

# %%
y_pred = regressor.predict(x)
y_pred
# Out:
# array([ 0.0362932 ,  0.25279975,  0.24329423,  0.53865708, -0.25155835,
#        -0.19933932,  0.72540066, -0.20320116,  0.06331784,  0.13495442,
#         0.04060816,  0.09014144,  0.07418497,  0.3577529 ,  0.26360837,
#         0.15990892,  0.03571099, -0.23563179, -0.19498205, -0.09013847,
#         0.04344337,  0.46967568,  0.03700438,  0.7321973 ,  0.19829577,
#         0.2709193 ,  0.14921552,  0.19697207,  0.04262563,  0.34775667,
#         0.19032138,  0.37337643,  0.28408839,  0.80291584,  0.58124829,
#         0.45205722,  0.55109339,  0.37548376,  0.40106812,  0.39215499,
#         0.47047202,  0.35543315,  0.44236375,  0.4046126 ,  0.4424895 ,
#         0.35183802,  0.54680789,  0.36590107,  0.41942603,  0.43401749,
#         0.37835868,  0.65458449])

# %%
df = pd.DataFrame({'Actual': y, 'Predicted': y_pred})
df
# Out:
#     Actual  Predicted
# 0        0   0.036293
# 1        0   0.252800
# 2        0   0.243294
# 3        1   0.538657
# 4        0  -0.251558
# 5        0  -0.199339
# 6        1   0.725401
# 7        0  -0.203201
# 8        0   0.063318
# 9        0   0.134954
# 10       0   0.040608
# 11       0   0.090141
# 12       0   0.074185
# 13       0   0.357753
# 14       0   0.263608
# 15       0   0.159909
# 16       0   0.035711
# 17       0  -0.235632
# 18       0  -0.194982
# 19       0  -0.090138
# 20       0   0.043443
# 21       0   0.469676
# 22       0   0.037004
# 23       1   0.732197
# 24       0   0.198296
# 25       0   0.270919
# 26       0   0.149216
# 27       1   0.196972
# 28       0   0.042626
# 29       0   0.347757
# 30       1   0.190321
# 31       0   0.373376
# 32       0   0.284088
# 33       1   0.802916
# 34       1   0.581248
# 35       0   0.452057
# 36       1   0.551093
# 37       0   0.375484
# 38       0   0.401068
# 39       0   0.392155
# 40       0   0.470472
# 41       0   0.355433
# 42       0   0.442364
# 43       1   0.404613
# 44       0   0.442490
# 45       0   0.351838
# 46       1   0.546808
# 47       1   0.365901
# 48       0   0.419426
# 49       1   0.434017
# 50       1   0.378359
# 51       1   0.654584

# %%
from sklearn import metrics 
print('R2- SCORE:', metrics.r2_score(y,y_pred))
# Out:
# R2- SCORE: 0.3258657666187109
