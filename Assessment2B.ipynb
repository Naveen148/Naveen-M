# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveen148/Naveen-M/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df = pd.concat(
    map(pd.read_csv, ['/content/college_1.csv', '/content/college_2.csv']), ignore_index=True)
print(df)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
data_exceeded = df[df["CodeKata Score"]>15000]
data_exceeded.to_csv("/content/drive")
data_exceeded
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# 1         Computer Science and Engineering       0        NaN
# 2         Computer Science and Engineering       0        NaN
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 84                     9.0

# %%
data_expected = df[(df["CodeKata Score"]>10000)&(df["CodeKata Score"]<15000)]
data_expected.to_csv("/content/drive")
data_expected
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3         Mugunthan S   100.0   47.0              10610           10610
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 87    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 3            Computer Science and Engineering       0        NaN
# 85           Computer Science and Engineering     340       20.0
# 86           Computer Science and Engineering    2000       55.0
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 3                      NaN
# 85                     0.0
# 86                     6.0
# 87                    -1.0

# %%
data_toimprove = df[(df["CodeKata Score"]>7000)&(df["CodeKata Score"]<10000)]
data_toimprove.to_csv("/content/drive")
data_toimprove
# Out:
#                        Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4               Sathammai.S   100.0    8.0               8980            8980
# 5              NIVEESHWAR S   100.0    0.0               8200            8200
# 6             KALAIARASAN K    85.0   47.0               7750            7880
# 7      MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 88                VIINU V P    -1.0   24.0               9150            9150
# 89               Poojitha Y     0.0   35.0               7210            8970
# 90   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 91                Gowtham R    -1.0    4.0               8650            8650
# 92                 shifak N    58.0    0.0               5180            8320
# 93                  Balaji     -1.0   20.0               6170            8160
# 94                 Rushitha    -1.0   62.0               7470            8090
# ...

# %%
data_unsatisfied = df[df["CodeKata Score"]<7000]
data_unsatisfied.to_csv("/content/drive")
data_unsatisfied
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8         J.SUGANTHI    27.0  50.00               5860            5860
# 9       thamizhpaana    29.0   0.00               5500            5500
# 10   Iyappan Samiraj    50.0  24.00               5400            5400
# 11      Ponniyamma.R   100.0  11.25               5380            5380
# 12         SABAPATHI   100.0   0.00               5280            5280
# ..               ...     ...    ...                ...             ...
# 114    praveen raj j    24.0   0.00               2380            2380
# 115       AMARNATH D    -1.0  12.00               1890            1890
# 116             bala    32.0   0.00               1720            1720
# 117             XY Z    -1.0  -1.00                  0               0
# 118        Hariharan    -1.0  -1.00                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avg1=df["Previous Geekions"].sum()/len(df["Name"])
avg2=df["CodeKata Score"].sum()/len(df["Name"])
print(avg1)
print(avg2)
# Out:
# 3842.3529411764707
# 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
df["Name"].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# python                      54.352941
# mysql                       23.500000
# Previous Geekions         3842.352941
# CodeKata Score            4051.764706
# Rising                     209.411765
# python_en                   29.657143
# computational_thinking       2.200000
# dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_star = df.sort_values(by=['Rising'],ascending=[False])
rising_star.head(3)
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 102        Computer Science and Engineering    2000       -1.0
# 86         Computer Science and Engineering    2000       55.0
#
#      computational_thinking
# 92                      0.0
# 102                     0.0
# 86                      6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
Shining_stars = df.sort_values(by=['Previous Geekions'],ascending=[False])
Shining_stars.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import plotly.express as px

# %%
fig = px.pie(df,values ="Previous Geekions",names="Department",title='DEPARTMENT WISE CODEKATA PERFORMANCE')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
fig = px.bar(df, x="Department", y="CodeKata Score", color="Name",title='DEPARTMENT WISE TOPPERS')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x="Department", y="CodeKata Score", color="Name",title='DEPARTMENT WISE TOPPERS')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x="Department", y="CodeKata Score", color="Name",title='DEPARTMENT WISE TOPPERS')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, x="Department", y="CodeKata Score", color="Name",title='DEPARTMENT WISE TOPPERS')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
